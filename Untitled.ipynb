# %%
import tkinter as tk
import customtkinter as ctk

import torch
import numpy as np
import pandas 

import cv2
from PIL import Image, ImageTk
import vlc
import random

app = tk.Tk()
app.geometry("600x600")
app.title("Drowsiness Detection")
ctk.set_appearance_mode("dark")


vidFrame = tk.Frame(height=480, width=600)
vidFrame.pack()
vid = ctk.CTkLabel(vidFrame)
vid.pack()

counter = 0
counterLabel = ctk.CTkLabel(master=app,text=counter,height=40, width=120, text_color="white", fg_color="teal")
counterLabel.pack(pady=10)

def resetcounter():
    global counter
    counter = 0
resetButton = ctk.CTkButton(master=app,text="Reset Counter", command = resetcounter,height=40, width=120, text_color="white", fg_color="teal")
resetButton.pack()


model = torch.hub.load('ultralytics/yolov5','custom', path='yolov5/runs/train/exp3/weights/last.pt', force_reload=True)
cap = cv2.VideoCapture(1)
def detect():
    global counter
    ret, frame = cap.read()
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    results = model(frame)
    img = np.squeeze(results.render())
    
    if len(results.xywh[0]) > 0:
        dconf = results.xywh[0][0][4]
        dclass = results.xywh[0][0][5]
        
        if dconf.item() > 0.60 and dclass.item() == 16:
            p = vlc.MediaPlayer()
            q = vlc.Media("1.wav")
            p.set_media(q)
            p.play()
            counter += 1
    
    imgarr = Image.fromarray(frame)
    imgtk = ImageTk.PhotoImage(imgarr)
    vid.imgtk = imgtk
    vid.configure(image=imgtk)
    vid.after(10,detect)
    counterLabel.configure(text=counter)
detect()
app.mainloop()
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\risha/.cache\torch\hub\master.zip
# YOLOv5  2023-8-5 Python-3.11.3 torch-2.0.1+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7055974 parameters, 0 gradients
# Adding AutoShape...

# %%
# !pip install -U ultralytics
# Out:
# Requirement already satisfied: ultralytics in c:\users\risha\anaconda3\lib\site-packages (8.0.133)
# Collecting ultralytics
#   Obtaining dependency information for ultralytics from https://files.pythonhosted.org/packages/85/38/541d6f06ab971c80408efcec6ec23f6ad0745722caf8055d9fcde8f6c223/ultralytics-8.0.147-py3-none-any.whl.metadata
#   Downloading ultralytics-8.0.147-py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: matplotlib>=3.2.2 in c:\users\risha\anaconda3\lib\site-packages (from ultralytics) (3.7.1)
# Requirement already satisfied: numpy>=1.22.2 in c:\users\risha\anaconda3\lib\site-packages (from ultralytics) (1.24.3)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\risha\anaconda3\lib\site-packages (from ultralytics) (4.8.0.74)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\risha\anaconda3\lib\site-packages (from ultralytics) (9.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\risha\anaconda3\lib\site-packages (from ultralytics) (6.0)
# Requirement already satisfied: requests>=2.23.0 in c:\users\risha\appdata\roaming\python\python311\site-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\risha\anaconda3\lib\site-packages (from ultralytics) (1.10.1)
# Requirement already satisfied: torch>=1.7.0 in c:\users\risha\appdata\roaming\python\python311\site-packages (from ultralytics) (2.0.1)
# Requirement already satisfied: torchvision>=0.8.1 in c:\users\risha\anaconda3\lib\site-packages (from ultralytics) (0.15.2)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\risha\appdata\roaming\python\python311\site-packages (from ultralytics) (4.65.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\risha\anaconda3\lib\site-packages (from ultralytics) (1.5.3)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\risha\anaconda3\lib\site-packages (from ultralytics) (0.12.2)
# Requirement already satisfied: psutil in c:\users\risha\anaconda3\lib\site-packages (from ultralytics) (5.9.0)
# Requirement already satisfied: py-cpuinfo in c:\users\risha\anaconda3\lib\site-packages (from ultralytics) (8.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\risha\anaconda3\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\risha\anaconda3\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\risha\anaconda3\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\risha\anaconda3\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\risha\anaconda3\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\risha\anaconda3\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\risha\anaconda3\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\risha\anaconda3\lib\site-packages (from pandas>=1.1.4->ultralytics) (2022.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\risha\appdata\roaming\python\python311\site-packages (from requests>=2.23.0->ultralytics) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\risha\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\risha\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\risha\appdata\roaming\python\python311\site-packages (from requests>=2.23.0->ultralytics) (2023.5.7)
# Requirement already satisfied: filelock in c:\users\risha\appdata\roaming\python\python311\site-packages (from torch>=1.7.0->ultralytics) (3.12.2)
# Requirement already satisfied: typing-extensions in c:\users\risha\anaconda3\lib\site-packages (from torch>=1.7.0->ultralytics) (4.6.3)
# Requirement already satisfied: sympy in c:\users\risha\anaconda3\lib\site-packages (from torch>=1.7.0->ultralytics) (1.11.1)
# Requirement already satisfied: networkx in c:\users\risha\appdata\roaming\python\python311\site-packages (from torch>=1.7.0->ultralytics) (3.1)
# Requirement already satisfied: jinja2 in c:\users\risha\appdata\roaming\python\python311\site-packages (from torch>=1.7.0->ultralytics) (3.1.2)
# Requirement already satisfied: colorama in c:\users\risha\appdata\roaming\python\python311\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\risha\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\risha\appdata\roaming\python\python311\site-packages (from jinja2->torch>=1.7.0->ultralytics) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\risha\anaconda3\lib\site-packages (from sympy->torch>=1.7.0->ultralytics) (1.2.1)
# Downloading ultralytics-8.0.147-py3-none-any.whl (606 kB)
#    ---------------------------------------- 0.0/606.2 kB ? eta -:--:--
#    -------- ------------------------------- 122.9/606.2 kB 3.6 MB/s eta 0:00:01
#    ------------------------ --------------- 368.6/606.2 kB 4.6 MB/s eta 0:00:01
#    ---------------------------------------  604.2/606.2 kB 5.4 MB/s eta 0:00:01
#    ---------------------------------------- 606.2/606.2 kB 3.8 MB/s eta 0:00:00
# Installing collected packages: ultralytics
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.0.133
#     Uninstalling ultralytics-8.0.133:
#       Successfully uninstalled ultralytics-8.0.133
# Successfully installed ultralytics-8.0.147
